# %% [markdown]
# # SALES PREDICTION USING PYTHON

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
sales_data=pd.read_csv('/content/advertising.csv')

# %%
sales_data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales_data.shape
# Out:
# (200, 4)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sales_data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
 #Check for missing values
print("Missing Values in Dataset:")
print(sales_data.isnull().sum())
# Out:
# Missing Values in Dataset:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
#TV vs Sales
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.scatter(sales_data['TV'], sales_data['Sales'], color='blue')
plt.title("TV vs Sales")
plt.xlabel("TV")
plt.ylabel("Sales")

#Radio vs Sales
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 2)
plt.scatter(sales_data['Radio'],sales_data["Sales"],c='blue')
plt.title("Radio vs Sales")
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.show()

#Newspaper vs Sales
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 3)
plt.scatter(sales_data['Newspaper'],sales_data["Sales"],c='blue')
plt.title("Newspaper vs Sales")
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()


plt.tight_layout()
plt.show()

# %%
# Histogram of Sales
plt.hist(sales_data['Sales'], color="green", edgecolor='white', bins=10)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
#Pairplot
sns.set(style="darkgrid")
sns.pairplot(sales_data)
plt.show()

# %%
#Regression Plot
sns.regplot(x='TV',y='Sales',data=sales_data)
plt.show()

sns.regplot(x='Radio',y='Sales',data=sales_data)
plt.show()

sns.regplot(x='Newspaper',y='Sales',data=sales_data)
plt.show()

# %%
sns.heatmap(sales_data.corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
#Displot for Sales Trend overtime
sns.displot(sales_data['Sales'],kde=True)
plt.title("Sales Trend Over Time")
plt.xlabel("Sales")
plt.ylabel("Frequency")
# Out:
# Text(17.31944444444445, 0.5, 'Frequency')

# %% [markdown]
# [link text](https://)Sales Highly coorelated with the tv

# %% [markdown]
# train our model using linear Regression as it is coorelated with only one variable TV

# %%
x_train,x_test,y_train,y_test=train_test_split(sales_data[['TV']],sales_data[['Sales']],test_size=0.3,random_state=0)

# %%
#Train Regresion model
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Predicction
result=model1.predict(x_test)
print(result)
# Out:
# [[10.93127621]
#  [ 9.88042193]
#  [12.09159447]
#  [22.99968079]
#  [16.45920756]
#  [10.21976029]
#  [ 7.6199906 ]
#  [20.28497391]
#  [ 8.4464437 ]
#  [17.95886418]
#  [21.44529217]
#  [11.91645209]
#  [15.71485245]
#  [17.42249065]
#  [11.32534656]
#  [13.72260788]
#  [21.68063975]
#  [ 7.18213465]
#  [11.23230217]
#  [18.82362968]
#  [22.88474361]
#  [14.82272095]
#  [16.72739433]
#  [14.35202581]
#  [10.07198391]
#  [13.88133066]
#  [16.20744039]
#  [18.36388094]
#  [19.40378881]
#  [ 8.51759529]
#  [10.85465142]
#  [18.03001578]
#  [22.50709285]
#  [20.3725451 ]
#  [ 7.86628457]
#  [ 8.16731053]
#  [10.40584907]
#  [17.03936669]
#  [10.88749061]
#  [ 8.51212209]
#  [ 9.16343282]
#  [ 8.86788005]
#  [14.96502414]
#  [18.61564811]
#  [18.93309367]
#  [12.76479799]
#  [ 7.6145174 ]
#  [ 8.06879294]
#  [14.02363385]
#  [12.86878878]
#  [13.15339515]
#  [19.70481478]
#  [21.03480222]
#  [17.26376787]
#  [ 9.59034237]
#  [10.55362545]
#  [23.17482317]
#  [16.58509115]
# ...

# %%
#Model Coefficient
print("Model Coefficent:-",model1.coef_)
print("Model Intercept:-",model1.intercept_)
# Out:
# Model Coefficent:- [[0.05473199]]
# Model Intercept:- [7.14382225]

# %%
# Model Evaluation
print("Mean Squared Error:", mean_squared_error(y_test, result))
print("R-squared Score:", r2_score(y_test, result))
# Out:
# Mean Squared Error: 5.569539193467241
# R-squared Score: 0.8150168765722069

# %%
# Plot Predictions
plt.scatter(x_test, y_test, label="Actual Data", color='blue')
plt.plot(x_test, result, color='red', label="Regression Line")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("TV vs Sales (Regression Model)")
plt.legend()
plt.show()

# %%
X = sales_data[['TV', 'Radio', 'Newspaper']]
y = sales_data[['Sales']]

# %%
#Model is been particularly fine but the only flaw is accuracy will not go high with this  predivtion only

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
model2 = LinearRegression()
model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_multi = model2.predict(x_test)

# %%
print("Multiple Linear Regression Coefficients:", model2.coef_)
print("Multiple Linear Regression Intercept:", model2.intercept_)
print("Multiple Regression Mean Squared Error:", mean_squared_error(y_test, pred_multi))
print("Multiple Regression R-squared Score:", r2_score(y_test, pred_multi))
# Out:
# Multiple Linear Regression Coefficients: [[0.05365017 0.11073062 0.00203697]]
# Multiple Linear Regression Intercept: [4.66924721]
# Multiple Regression Mean Squared Error: 3.9380152204802865
# Multiple Regression R-squared Score: 0.8692052734910128
